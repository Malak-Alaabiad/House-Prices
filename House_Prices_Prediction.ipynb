# %% [markdown]
# #Read the data

# %%
import pandas as pd
data = pd.read_csv('/content/house_prices.csv')

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0       3.0       1.00       1180.0
# 1  6414100192  20141209T000000  538000.0       3.0       2.25       2570.0
# 2  5631500400  20150225T000000  180000.0       2.0       1.00        770.0
# 3  2487200875  20141209T000000  604000.0       4.0       3.00       1960.0
# 4  1954400510  20150218T000000  510000.0       3.0       2.00       1680.0
#
#    sqft_lot  floors waterfront  view  ... grade  sqft_above  sqft_basement  \
# 0    5650.0     1.0          N   0.0  ...   7.0      1180.0            0.0
# 1    7242.0     2.0          N   0.0  ...   7.0      2170.0          400.0
# 2   10000.0     1.0          N   0.0  ...   6.0       770.0            0.0
# 3    5000.0     1.0          N   0.0  ...   7.0      1050.0          910.0
# 4    8080.0     1.0          N   0.0  ...   8.0      1680.0            0.0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0    1955.0           0.0  98178.0  47.5112 -122.257         1340.0
# 1    1951.0        1991.0  98125.0  47.7210 -122.319         1690.0
# 2    1933.0           0.0  98028.0  47.7379 -122.233         2720.0
# 3    1965.0           0.0  98136.0  47.5208 -122.393         1360.0
# 4    1987.0           0.0  98074.0  47.6168 -122.045         1800.0
#
#    sqft_lot15
# 0      5650.0
# 1      7639.0
# 2      8062.0
# 3      5000.0
# 4      7503.0
#
# [5 rows x 21 columns]

# %%
data = data.drop(['id', 'date', 'zipcode'], axis = 1)

# %%
data.isnull().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (18325, 18)

# %%
data.sample(5)
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 15521  727160.0       7.0       3.75       2310.0    5000.0     2.0
# 415    570000.0       3.0       1.75       2910.0   37461.0     1.0
# 17939  424000.0       3.0       2.00       1330.0    5632.0     1.0
# 12626  209900.0       2.0       2.00       1180.0    3003.0     2.0
# 10049  439000.0       4.0       2.50       2690.0    9551.0     2.0
#
#       waterfront  view condition  grade  sqft_above  sqft_basement  yr_built  \
# 15521          N   0.0   Average    8.0      2310.0            0.0    1984.0
# 415            N   0.0      Good    7.0      1530.0         1380.0    1967.0
# 17939          N   0.0   Average    8.0      1330.0            0.0    1988.0
# 12626          N   0.0   Average    6.0      1180.0            0.0    2005.0
# 10049          N   0.0   Average    9.0      2690.0            0.0    1992.0
#
#        yr_renovated      lat     long  sqft_living15  sqft_lot15
# 15521           0.0  47.6781 -122.376         1360.0      1552.0
# 415             0.0  47.7015 -122.164         2520.0     18295.0
# 17939           0.0  47.5745 -122.017         1900.0      4842.0
# 12626           0.0  47.3491 -122.020         1310.0      3003.0
# 10049           0.0  47.4343 -122.156         2890.0      9121.0

# %% [markdown]
# #Get some insights
#
# 1. number of each condition in the data
# 2. avg prices
# 3. distinct values for(view, grade)

# %%
data['condition'].value_counts()
# Out:
# condition
# Average      11279
# Good          5293
# Very Good     1568
# Fair           159
# Poor            26
# Name: count, dtype: int64

# %%
data['price'].mean()
# Out:
# 533463.3531787175

# %%
df2 = data.iloc[:, [8, 0]]

# %%
df2.head()
# Out:
#    condition     price
# 0    Average  221900.0
# 1    Average  538000.0
# 2    Average  180000.0
# 3  Very Good  604000.0
# 4    Average  510000.0

# %%
df = pd.concat([data['condition'], data['price']], axis = 1)

# %%
df.head()
# Out:
#    condition     price
# 0    Average  221900.0
# 1    Average  538000.0
# 2    Average  180000.0
# 3  Very Good  604000.0
# 4    Average  510000.0

# %%
df.groupby(['condition']).mean()
# Out:
#                    price
# condition
# Average    532565.949109
# Fair       330547.069182
# Good       520301.863782
# Poor       295613.461538
# Very Good  608867.288265

# %%
data['view'].value_counts()
# Out:
# view
# 0.0    16458
# 2.0      857
# 3.0      441
# 1.0      287
# 4.0      282
# Name: count, dtype: int64

# %% [markdown]
# #Data Preprocessing

# %%
x = data.iloc[:, 1:]

# %%
y = data.iloc[:, 0:1]

# %%
y
# Out:
#            price
# 0       221900.0
# 1       538000.0
# 2       180000.0
# 3       604000.0
# 4       510000.0
# ...          ...
# 18324   655000.0
# 18325   255000.0
# 18326   215000.0
# 18327  1265000.0
# 18328  2920000.0
#
# [18325 rows x 1 columns]

# %%
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  view  \
# 0       3.0       1.00       1180.0    5650.0     1.0          N   0.0
# 1       3.0       2.25       2570.0    7242.0     2.0          N   0.0
# 2       2.0       1.00        770.0   10000.0     1.0          N   0.0
# 3       4.0       3.00       1960.0    5000.0     1.0          N   0.0
# 4       3.0       2.00       1680.0    8080.0     1.0          N   0.0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0    Average    7.0      1180.0            0.0    1955.0           0.0
# 1    Average    7.0      2170.0          400.0    1951.0        1991.0
# 2    Average    6.0       770.0            0.0    1933.0           0.0
# 3  Very Good    7.0      1050.0          910.0    1965.0           0.0
# 4    Average    8.0      1680.0            0.0    1987.0           0.0
#
#        lat     long  sqft_living15  sqft_lot15
# 0  47.5112 -122.257         1340.0      5650.0
# 1  47.7210 -122.319         1690.0      7639.0
# 2  47.7379 -122.233         2720.0      8062.0
# 3  47.5208 -122.393         1360.0      5000.0
# 4  47.6168 -122.045         1800.0      7503.0

# %%
x['condition'].unique()
# Out:
# array(['Average', 'Very Good', 'Good', 'Poor', 'Fair'], dtype=object)

# %%
def transform(c):
  if c == 'Poor':
    return 1
  elif c == 'Fair':
    return 2
  elif c == 'Average':
    return 3
  elif c == 'Good':
    return 4
  elif c == 'Very Good':
    return 5
  else:
    return c

# %%
x['condition'] =  x['condition'].apply(transform)

# %%
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  view  \
# 0       3.0       1.00       1180.0    5650.0     1.0          N   0.0
# 1       3.0       2.25       2570.0    7242.0     2.0          N   0.0
# 2       2.0       1.00        770.0   10000.0     1.0          N   0.0
# 3       4.0       3.00       1960.0    5000.0     1.0          N   0.0
# 4       3.0       2.00       1680.0    8080.0     1.0          N   0.0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3    7.0      1180.0            0.0    1955.0           0.0
# 1          3    7.0      2170.0          400.0    1951.0        1991.0
# 2          3    6.0       770.0            0.0    1933.0           0.0
# 3          5    7.0      1050.0          910.0    1965.0           0.0
# 4          3    8.0      1680.0            0.0    1987.0           0.0
#
#        lat     long  sqft_living15  sqft_lot15
# 0  47.5112 -122.257         1340.0      5650.0
# 1  47.7210 -122.319         1690.0      7639.0
# 2  47.7379 -122.233         2720.0      8062.0
# 3  47.5208 -122.393         1360.0      5000.0
# 4  47.6168 -122.045         1800.0      7503.0

# %%
x = pd.get_dummies(x)

# %%
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  view  condition  grade  \
# 0       3.0       1.00       1180.0    5650.0     1.0   0.0          3    7.0
# 1       3.0       2.25       2570.0    7242.0     2.0   0.0          3    7.0
# 2       2.0       1.00        770.0   10000.0     1.0   0.0          3    6.0
# 3       4.0       3.00       1960.0    5000.0     1.0   0.0          5    7.0
# 4       3.0       2.00       1680.0    8080.0     1.0   0.0          3    8.0
#
#    sqft_above  sqft_basement  yr_built  yr_renovated      lat     long  \
# 0      1180.0            0.0    1955.0           0.0  47.5112 -122.257
# 1      2170.0          400.0    1951.0        1991.0  47.7210 -122.319
# 2       770.0            0.0    1933.0           0.0  47.7379 -122.233
# 3      1050.0          910.0    1965.0           0.0  47.5208 -122.393
# 4      1680.0            0.0    1987.0           0.0  47.6168 -122.045
#
#    sqft_living15  sqft_lot15  waterfront_N  waterfront_Y
# 0         1340.0      5650.0          True         False
# 1         1690.0      7639.0          True         False
# 2         2720.0      8062.0          True         False
# 3         1360.0      5000.0          True         False
# 4         1800.0      7503.0          True         False

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_x = MinMaxScaler(feature_range=(0,1))
scaler_y = MinMaxScaler(feature_range=(0,1))
x = scaler_x.fit_transform(x)
y = scaler_y.fit_transform(y)

# %%
x
# Out:
# array([[0.09090909, 0.125     , 0.06150342, ..., 0.00573207, 1.        ,
#         0.        ],
#        [0.09090909, 0.28125   , 0.16704632, ..., 0.00801686, 1.        ,
#         0.        ],
#        [0.06060606, 0.125     , 0.03037206, ..., 0.00850277, 1.        ,
#         0.        ],
#        ...,
#        [0.09090909, 0.125     , 0.06378132, ..., 0.00596182, 1.        ,
#         0.        ],
#        [0.09090909, 0.21875   , 0.14198937, ..., 0.00574012, 1.        ,
#         0.        ],
#        [0.12121212, 0.59375   , 0.31928626, ..., 0.01036943, 1.        ,
#         0.        ]])

# %%
y
# Out:
# array([[0.01926557],
#        [0.06072131],
#        [0.01377049],
#        ...,
#        [0.01836066],
#        [0.15606557],
#        [0.37311475]])

# %%
def transform(value):
  value = str(value)
  value = float(value.split([0]))
  return value

# %%
output = '0.06072131 USD'

# %%
float(output.split()[0])
# Out:
# 0.06072131

# %%
output = scaler_y.inverse_transform([[float(output.split()[0])]])

# %%
output
# Out:
# array([[537999.98875]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %% [markdown]
# #Welcome to AI

# %% [markdown]
# #Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()
model1.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model1.score(x_test, y_test) * 100
# Out:
# 68.45840319107874

# %% [markdown]
# #PLoynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 2)
x_new = poly.fit_transform(x)

# %%
x_train2, x_test2, y_train2, y_test2 = train_test_split(x_new, y, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
model2 = LinearRegression()
model2.fit(x_train2, y_train2)
# Out:
# LinearRegression()

# %%
model2.score(x_train2, y_train2) * 100
# Out:
# 82.36730604826109

# %%
model2.score(x_test2, y_test2) * 100
# Out:
# 78.49453013228387

# %% [markdown]
# # Support vector machine

# %%
from sklearn.svm import SVR
model3 = SVR()
model3.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
model3.score(x_train, y_train) * 100
# Out:
# 29.829702236421372

# %%
model3.score(x_test, y_test) * 100
# Out:
# 6.251189396073564

# %% [markdown]
# #DT

# %%
from sklearn.tree import DecisionTreeRegressor
model4 = DecisionTreeRegressor()
model4.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
model4.score(x_train, y_train) * 100
# Out:
# 99.92809257278995

# %%
model4.score(x_test, y_test) * 100
# Out:
# 64.51572704014077

# %% [markdown]
# #RF

# %%
from sklearn.ensemble import RandomForestRegressor
model5 = RandomForestRegressor(n_estimators = 100)
model5.fit(x_train, y_train)
# Out:
# <ipython-input-62-972094fc4846>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model5.fit(x_train, y_train)
# RandomForestRegressor()

# %%
model5.score(x_train, y_train) * 100
# Out:
# 0.9821892704720657

# %%
model5.score(x_test, y_test) * 100
# Out:
# 83.22763783503979

# %% [markdown]
# #XG

# %%
from xgboost import XGBRegressor
model6 = XGBRegressor(n_estimators = 100)
model6.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
model6.score(x_train, y_train) * 100
# Out:
# 97.70094955519436

# %%
model6.score(x_test, y_test) * 100
# Out:
# 86.30602268455338

# %%
import pickle
pickle.dump(model5, open('myweights.sav', 'wb'))

# %%
inputs = [[3, 1.00, 1180, 5650, 1.0, 0, 3, 7, 1180.0, 0.0, 1955, 0, 47.5112, -122.257, 1340.0, 5650.0, 1, 0]]

# %%
loadedModel = pickle.load(open('/content/myweights.sav', 'rb'))

# %%
output = scaler_x.transform(inputs)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
output = loadedModel.predict(output)

# %%
output
# Out:
# array([0.02139633])

# %%
output = scaler_y.inverse_transform([output])

# %%
output
# Out:
# array([[238147.05]])

# %%
print(f'the price is {int(output[0][0])} USD')
# Out:
# the price is 238147 USD
